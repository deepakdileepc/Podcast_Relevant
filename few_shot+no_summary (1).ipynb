# %%
# !pip install  pyyaml
# !pip install openai==0.28 python-dotenv
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (6.0.2)
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from openai==0.28) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from openai==0.28) (4.67.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from openai==0.28) (3.11.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28) (2025.1.31)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (1.20.0)
# Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 3.3 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.76.0
#     Uninstalling openai-1.76.0:
#       Successfully uninstalled openai-1.76.0
# Successfully installed openai-0.28.0 python-dotenv-1.1.0

# %%
import os
import openai
from dotenv import load_dotenv
load_dotenv()
# Set up your OpenAI API key
os.environ["OPENAI_API_KEY"] = "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"

openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
def classify_text(input_text):
    """Classify a text segment as casual or not casual conversation based on its tone and informational content."""

    prompt = f"""
    Task:
    Classify the following text segment as CASUAL or NOT CASUAL based on its tone and the presence of meaningful information.

    Guidelines:

    CASUAL:
    The segment reflects informal, off-topic, or filler conversation.
    It provides little to no meaningful or informative content.
    Examples: Jokes, small talk, sponsor messages, personal anecdotes, or unrelated commentary.

    NOT CASUAL:
    The segment is informative, instructional, or provides clear value.
    It presents ideas, insights, or content that could be useful or educational, even if the tone is informal.
    Examples: Explanations, discussions, instructions, or arguments that carry substance or purpose.

    Strict Rule:
    Classify a segment as CASUAL only if it clearly lacks any meaningful or informative value.

    Additional Examples of CASUAL Segments:
    - "Yeah, well, it is what it is, you know?" (Casual way of stating the obvious.)
    - "Eh, could be better, could be worse, right?" (Laid-back and vague comparison.)
    - "Huh, that's kinda interesting, I guess." (Casual and non-committal reaction.)
    - "Yup, stuff's just kinda happening." (Very casual and uninformative.)
    - "We'll see what happens, I guess." (Casual way of saying "time will tell.")

    VIDEO SUMMARY : {input_summary}
    INPUT TEXT: {input_text}

    OUTPUT:
    - Classification: (CASUAL / NOT CASUAL)
    - Explanation: Provide a brief reasoning (up to 50 words) explaining why the classification was chosen,
                   referring to the tone, purpose, and content of the text segment.
    """

    try:
        response = openai.Completion.create(
            model="gpt-3.5-turbo-instruct",
            prompt=prompt,
            max_tokens=70,
            temperature=0.7
        )

        response_text = response.choices[0].text.strip()

        classification = None
        explanation = None

        if "not casual" in response_text.lower():
            classification = "NOT CASUAL"
        elif "casual" in response_text.lower():
            classification = "CASUAL"
        else:
            print(f"Unexpected response format: {response_text}")

        if "Explanation:" in response_text:
            explanation_start = response_text.find("Explanation:") + len("Explanation:")
            explanation = response_text[explanation_start:].strip()

        return {
            'input_text': input_text,
            'classification': classification,
            'explanation': explanation
        }

    except Exception as e:
        print(f"Error with API call: {e}")
        return {
            'input_text': input_text,
            'classification': None,
            'explanation': "API call failed."
        }
def classify_texts(input_texts):
    """
    Sequentially classify multiple text segments.
    """
    results = []
    for text in input_texts:
        result = classify_text(text)
        results.append(result)
    return results

# %%
import yaml

# Load the transcript
with open('input.yaml', 'r') as file:
    data = yaml.safe_load(file)

# Extract input texts
input_texts = [d['text'] for d in data]


# Run classification sequentially
results = classify_texts(input_texts)

# Save results to a pickle file
import pickle
with open("results.pkl", 'wb') as file:
    pickle.dump(results, file)

# Reload and display a few results
with open("results.pkl", 'rb') as file:
    results = pickle.load(file)

# Display the first two results
for result in results[:2]:
    print(result)
# Out:
# Unexpected response format: Classifica
# {'input_text': 'Airbnb has these things called categories.', 'classification': 'NOT CASUAL', 'explanation': 'The segment provides clear and informative content by introducing a specific feature of Airbnb, namely categories. \n    This is done in a direct and factual manner, which suggests a purposeful and instructional tone.'}
# {'input_text': "Treehouses, cabins, Shrek's swamp.", 'classification': 'CASUAL', 'explanation': 'The segment is casual because it is a list of unrelated and whimsical items that do not provide any meaningful or instructive information. The tone is playful and non-committal, and the purpose is simply to list random things.'}

# %%
import pandas as pd
# Reload results
with open("results.pkl", 'rb') as file:
    results = pickle.load(file)

# Convert results to a DataFrame and display as a table
df = pd.DataFrame(results)[['input_text', 'classification', 'explanation']]
print(df)
# Out:
#                                        input_text classification  \
# 0      Airbnb has these things called categories.     NOT CASUAL
# 1              Treehouses, cabins, Shrek's swamp.         CASUAL
# 2                   I literally went to that one.         CASUAL
# 3    I've stayed in quite a few categories so far         CASUAL
# 4            and out of all of the videos I make,         CASUAL
# ..                                            ...            ...
# 694                              Give it a watch.         CASUAL
# 695                        You guys are the best.         CASUAL
# 696         I had so much fun filming this video.     NOT CASUAL
# 697                                     Love you.         CASUAL
# 698                                          Bye.         CASUAL
#
#                                            explanation
# 0    The segment provides clear and informative con...
# 1    The segment is casual because it is a list of ...
# 2    The tone of the text is nonchalant and lacks a...
# 3    The tone is casual and laid-back, with phrases...
# 4    The text segment provides little to no meaning...
# ..                                                 ...
# 694  This segment is very casual in tone and provid...
# 695  The text segment is a casual compliment with n...
# 696  The tone of the text is casual, but the purpos...
# 697  The text segment "Love you" is classified as C...
# 698  This text segment is very brief and does not p...
#
# [699 rows x 3 columns]

# %%
# Save to an Excel file
df.to_excel("classification_results.xlsx", index=False)

print("Results saved to classification_results.xlsx")
# Out:
# Results saved to classification_results.xlsx

# %%
import pandas as pd
import pickle

# Load results
with open("results.pkl", "rb") as file:
    results = pickle.load(file)

# Convert results to DataFrame
df = pd.DataFrame(results)[["input_text", "classification", "explanation"]]

# Save the original DataFrame before removing casual segments
df.to_excel("before_removal.xlsx", index=False)

# Function to remove groups of 3 or more consecutive casual segments
def remove_consecutive_casual(df):
    df["keep"] = True  # Mark all rows to keep by default
    casual_count = 0  # Counter for consecutive casual segments

    for i in range(len(df)):
        if df.loc[i, "classification"] == "CASUAL":  # Casual segment
            casual_count += 1
        else:
            if casual_count >= 3:
                # Remove the previous casual segment group
                df.loc[i - casual_count : i - 1, "keep"] = False
            casual_count = 0  # Reset count for non-casual segment

    # Final check if last segments were casual
    if casual_count >= 3:
        df.loc[len(df) - casual_count : len(df) - 1, "keep"] = False

    return df[df["keep"]].drop(columns=["keep"]).reset_index(drop=True)

# Apply the function
df_cleaned = remove_consecutive_casual(df)

# %%
import pandas as pd

# Load the labeled dataset from Excel
file_path = "labeled.xlsx"  # Replace with your actual file name
df = pd.read_excel(file_path)

# Display the first few rows to verify
print(df.head())
# Out:
#      end  start                                          text  label
# 0   2.92   0.00    Airbnb has these things called categories.      0
# 1   5.32   2.92            Treehouses, cabins, Shrek's swamp.      0
# 2   6.68   5.32                 I literally went to that one.      1
# 3   9.04   6.68  I've stayed in quite a few categories so far      1
# 4  10.84   9.04          and out of all of the videos I make,      1

# %%
import pandas as pd

def remove_consecutive_casual(df):
    df = df.copy()  # Ensure we don’t modify the original DataFrame
    df["keep"] = True  # Mark all rows to keep by default

    casual_count = 0  # Counter for consecutive casual segments
    start_index = None  # Track start of consecutive casuals

    for i in range(len(df)):
        if df.loc[i, "label"] == 1:  # Casual segment
            if casual_count == 0:
                start_index = i  # Mark the start of casual sequence
            casual_count += 1
        else:
            if casual_count >= 3:
                # Mark the previous casual segments for removal
                df.loc[start_index:i - 1, "keep"] = False
            casual_count = 0  # Reset count for non-casual segment

    # Final check if the last segments were casual
    if casual_count >= 3:
        df.loc[start_index:len(df) - 1, "keep"] = False

    return df[df["keep"]].drop(columns=["keep"]).reset_index(drop=True)


df_original_labeled_removed = remove_consecutive_casual(df)  # Process it
print(df)
# Out:
#          end    start                                          text  label
# 0       2.92     0.00    Airbnb has these things called categories.      0
# 1       5.32     2.92            Treehouses, cabins, Shrek's swamp.      0
# 2       6.68     5.32                 I literally went to that one.      1
# 3       9.04     6.68  I've stayed in quite a few categories so far      1
# 4      10.84     9.04          and out of all of the videos I make,      1
# ..       ...      ...                                           ...    ...
# 694  1631.78  1630.78                              Give it a watch.      1
# 695  1632.28  1631.78                        You guys are the best.      1
# 696  1633.78  1632.28         I had so much fun filming this video.      1
# 697  1634.28  1633.78                                     Love you.      1
# 698  1634.78  1634.28                                          Bye.      1
#
# [699 rows x 4 columns]

# %%
def compute_jaccard(df_human, df_llm, human_col='text', llm_col='input_text'):
    # Extract sentences as sets
    human_sentences = set(df_human[human_col].tolist())
    llm_sentences = set(df_llm[llm_col].tolist())

    # Compute intersection and union
    intersection = human_sentences & llm_sentences
    union = human_sentences | llm_sentences

    # Calculate Jaccard Similarity
    jaccard_similarity = len(intersection) / len(union) if len(union) > 0 else 0

    # Output details
    print("Human-filtered sentences:", human_sentences)
    print("LLM-filtered sentences:", llm_sentences)
    print("Intersection (common sentences):", intersection)
    print("Union (all sentences):", union)
    print(f"Jaccard Similarity: {jaccard_similarity:.4f}")

    return jaccard_similarity

# Apply Jaccard Similarity
jaccard_score = compute_jaccard(df_original_labeled_removed, df_cleaned)
# Out:
# Human-filtered sentences: {'And lastly, my favorite part so far.', 'A shower.', 'Is this normal in Paris?', 'Does anyone know what this is?', "Carlos says it's much better than the photos.", 'There were views for this farm.', "Oh my gosh, they're so stinkin' cute.", 'Oh, thank goodness.', 'the pasta sauce stains out of the crevices of my lips.', 'Starting with boats.', "I might don't be surprised by this vanist one day.", 'We are gonna sit on this balcony and look at the Eiffel Tower', 'Well, I see why they call this one luxury.', 'Room.', "But it doesn't look real. It's kind of furry.", 'Why is the PS4 mounted like that?', 'A beautiful vanity with lots and lots of French pastries.', 'This must be for when the kids are grounded.', 'They say things like, beautiful camp, peaceful getaway.', 'And lastly, a shower.', "And it's not every day you get to feel like that.", 'Collette kind of reminds me of Haley.', 'I mean, if you take a look at the shampoo and conditioner, they look rock solid.', 'I did find the big sign that says farm.', 'Because I actually just came here for a toilet here.', 'No running water at this farm.', 'I want to explore it.', 'but nope. Not here.', "Let's see.", "because that's probably the most fun and romantic thing we could possibly do right now.", "This is making me feel lonely, but that's fine.", "There's another living room with a PS4.", 'The slide is really fun.', "If there's anything that is good for the soul, it's going to Chili's by yourself,", 'I cannot express how fun this is.', "It doesn't make sense.", 'But coming to this farm, this feels like...', "where he's gonna take me out into the ocean", 'And right next to it is a small little kitchen.', 'I was not able to get connected during the duration of my stay.', "I'm pretty sure it's in this one.", 'This feels restful. It feels like I won some sort of prize.', 'Okay, okay, we need a tour.', "They're good.", 'This is just such a good movie.', 'Camping was awesome.', 'The property is 3.4 million.', "There's no running water.", 'I actually wonder like what are these people do all day?', 'I fit in here fine.', "But what's it going to be like inside?", 'You know I went straight for that coffee maker so I could use one of these cute little', "So I don't know if it'll survive all the way to Paris,", 'All right.', "Every object in this house is like 400 percent, it's normal size.", "Lastly, I'm heading downstairs to check out this water slide.", "I feel like I'm going to fall through.", 'Yesterday I was camping in the woods.', 'I looked it up.', 'A fridge, a microwave, and a cute little oven.', 'Today I have a red Tesla in the driveway.', 'And that is pretty cool.', 'Perfect.', "How's this gonna work?", "I have a feeling it's going to take a pretty long time to explore our home for the night.", "It's about 1,200 miles.", 'Yeah, that was awesome.', "I don't know which one is the one that I'm staying in.", 'We just slept for 12 hours and this is the only Airbnb of the video that we are staying for two nights.', "I've got to say I've had so much fun so far on this trip.", 'a seating area behind the seating area.', "You're gonna go to the living room.", 'Oh yeah, it works.', 'Look at how beautiful this cabinet is.', 'So here goes nothing.', 'I decided to test out the bed and noticed this.', 'In conclusion, I love the farm.', 'but it also has a passenger seat and right behind that, a full-size dining table.', "There's a really nice seating area.", "This Airbnb not only has a driver's seat with a steering wheel and some old buttons,", "Guess who's doing a campfire tonight?", 'Bottom level.', 'which is crazy that it might be potentially even bigger.', 'going to work.', "It's a hangout area made out of net.", "Whoa, I want to wish we'd watch tonight.", 'Look at this tractor.', "In case you've been living on a farm,", 'There is a lot more going on outside though.', "I'm technically flying right now.", "I feel like I'm in an AI generative fill living room right now. ...
# LLM-filtered sentences: {'And lastly, my favorite part so far.', 'to Gustos.', 'That time I wrote a train through Europe.', 'Neither of us are really good at cooking, but it seems romantic.', 'A shower.', 'But the fact that I can get Taco Bell is 15 minutes here.', 'Come back.', "Carlos says it's much better than the photos.", 'Does anyone know what this is?', 'There were views for this farm.', 'We are simply Texans.', 'I am back from my charter.', 'that boats had beds in them until I watched', 'So we picked up some merchandise that will help us blend in.', 'the pasta sauce stains out of the crevices of my lips.', 'I placed the order for Taco Bell and my door dasher arrived quick.', 'Starting with boats.', "Don't worry, everybody.", 'I had to look it up.', 'Hey, how are you?', 'We are gonna sit on this balcony and look at the Eiffel Tower', "So we already know that I want to take Haley to the equivalent of Gusto's in Ratatouille", 'Well, I see why they call this one luxury.', "But it doesn't look real. It's kind of furry.", 'Why is the PS4 mounted like that?', 'A beautiful vanity with lots and lots of French pastries.', 'This must be for when the kids are grounded.', 'They say things like, beautiful camp, peaceful getaway.', "And it's not every day you get to feel like that.", 'I mean, if you take a look at the shampoo and conditioner, they look rock solid.', 'Give it a watch.', 'That video taught me a lot of things.', 'I did feel a little uncomfortable because I was worried that people thought this was my', 'I did find the big sign that says farm.', 'Oh my gosh.', 'No running water at this farm.', 'The chickens would not leave.', 'I want to explore it.', "go follow Joyride's Weets on Instagram.", 'but nope. Not here.', "because that's probably the most fun and romantic thing we could possibly do right now.", 'Those are pretty cool.', "This is making me feel lonely, but that's fine.", 'And I found this one. I really like this one.', "There's another living room with a PS4.", 'I need to call a guy named Captain Joseph.', "I'm clean.", "Meanwhile, I'm just watching Ratatouille every night.", 'The slide is really fun.', "but it's actually a guy named Albert.", "If there's anything that is good for the soul, it's going to Chili's by yourself,", 'I enjoyed my Doritos Locos Tacos and then decided to make a campfire.', 'I cannot express how fun this is.', 'I spent some time looking around the flower field', "Here's my list.", "It doesn't make sense.", 'But coming to this farm, this feels like...', 'Great, great.', "It was no Raditui, but if you can't tell, I'm really excited to watch Raditui.", 'And right next to it is a small little kitchen.', "We didn't even think about the fact that there's no oven in here.", 'I was not able to get connected during the duration of my stay.', 'more excited for Paris.', "I'm pretty sure it's in this one.", 'This feels restful. It feels like I won some sort of prize.', 'and get yourself a bag of Joyride.', 'I made it to the boats.', 'Okay, okay, we need a tour.', 'They named our school after it.', "They're good.", 'This is just such a good movie.', 'That dinner was so good.', 'Camping was awesome.', "Come back at 9 o'clock.", 'Again, we will cross that bridge when we get to it.', 'The property is 3.4 million.', "First of all, I'm a rat.", "There's no running water.", 'Here he is.', 'I fit in here fine.', 'Good morning.', "But what's it going to be like inside?", 'You guys are the best.', 'You know I went straight for that coffee maker so I could use one of these cute little', "So I don't know if it'll survive all the way to Paris,", 'All right.', "So that's my dream.", "Every object in this house is like 400 percent, it's normal size.", "I'm excited to go to Paris and I'm excited to see Haley.", "Lastly, I'm heading downstairs to check out this water slide.", "I'm actually amazing.", "I'm out to not order Taco Bell in this video again.", "I feel like I'm going to fall through.", 'This is me.', 'Okay, ...
# Intersection (common sentences): {'The entryway, the bedroom, the bathroom, and the living room.', 'And lastly, my favorite part so far.', 'Man, these categories switch up quick.', 'This apartment is comprised of four simple rooms.', "Let's go to Miami.", 'There are so many bedrooms in this house.', 'This bedroom is so cool.', 'Yeah, this place is luxury.', 'It seems as though I have arrived to the boat.', 'A shower.', 'Camping.', 'But then we have the best day in Paris ever of all time tomorrow.', 'Does anyone know what this is?', "Carlos says it's much better than the photos.", 'There were views for this farm.', 'Look at how beautiful this cabinet is.', 'Air conditioning.', 'They left a camera in the Airbnb.', 'I saved the best for last.', 'So the inside of the camper is obviously awesome.', 'A washer, but no dryer.', 'One photo only.', 'I decided to test out the bed and noticed this.', 'Looks like a very nice showerhead hot water, cold water, shampoo and conditioner from', 'In conclusion, I love the farm.', 'A TV, a first aid kit.', 'the pasta sauce stains out of the crevices of my lips.', 'but it also has a passenger seat and right behind that, a full-size dining table.', "Alright, let's go back to Florida.", "I'm just going to cut some flowers.", "There's a really nice seating area.", 'Starting with boats.', "It's actually a queen-sized bed.", "This Airbnb not only has a driver's seat with a steering wheel and some old buttons,", "I hear that's rare.", 'You might not be that impressed by this Airbnb behind me, but look at the list.', 'It comes with a huge bathtub massive.', 'coming home to an empty mansion sitting in your home movie theater and watching Ratatouille.', 'This boat is a lot bigger than I expected.', 'So this mansion behind me is in the luxury category on Airbnb.', 'this millennium.', 'Next I walked into a bedroom.', 'We are gonna sit on this balcony and look at the Eiffel Tower', 'Well, I see why they call this one luxury.', "I'm going to need a picture with all three.", "That's okay, because I have this.", "But it doesn't look real. It's kind of furry.", "Whoa, I want to wish we'd watch tonight.", "I'm walking into what I assume is the master bedroom.", 'A bathroom.', 'I was curious.', 'You might have been anticipating a joke of some sort,', 'Why is the PS4 mounted like that?', 'A beautiful vanity with lots and lots of French pastries.', "They haven't been touched in a while.", 'Look at this tractor.', 'This must be for when the kids are grounded.', 'They say things like, beautiful camp, peaceful getaway.', 'This is so cool.', 'The upper level, the main level, and the living area.', 'When your couch means a couch, you guys should see this kitchen.', "The patio deck has RGB lights, and there's a speaker in here, the size of a small vehicle.", 'Every single house in this neighborhood is massive.', "I don't know.", "I think there's three stories on this boat.", 'There is a lot more going on outside though.', 'No way.', 'Just a few steps away from the cabin is an outhouse.', "I'm technically flying right now.", 'Here we go.', "I feel like I'm in an AI generative fill living room right now.", "And it's not every day you get to feel like that.", "At least I think that's what's under all that.", 'I mean, if you take a look at the shampoo and conditioner, they look rock solid.', 'I think I just suffered a minor tear in my knee just now.', 'The boat was incredible.', 'This is 100% the reason.', 'mugs, and that I did.', "It's beautiful. And I just cut it for Haley.", 'this Airbnb comes with a two hour charter', 'And that was the only one star review.', 'The cabin behind me is 168 square feet.', "I don't think I'm allowed to drive it.", 'Yeah, I guess so.', 'I did find the big sign that says farm.', "There's also a great seating area with a fire pit, a grill,", 'Anyways, the door across from that one is a bedroom.', 'No running water at this farm.', 'I want to explore it.', 'People love it here.', 'Toiletries.', "I'm  ...
# Union (all sentences): {'And lastly, my favorite part so far.', 'to Gustos.', 'That time I wrote a train through Europe.', 'Neither of us are really good at cooking, but it seems romantic.', 'A shower.', 'Is this normal in Paris?', 'But the fact that I can get Taco Bell is 15 minutes here.', 'Does anyone know what this is?', "Carlos says it's much better than the photos.", 'Come back.', 'There were views for this farm.', 'We are simply Texans.', 'I am back from my charter.', 'that boats had beds in them until I watched', "Oh my gosh, they're so stinkin' cute.", 'So we picked up some merchandise that will help us blend in.', 'Oh, thank goodness.', 'the pasta sauce stains out of the crevices of my lips.', 'I placed the order for Taco Bell and my door dasher arrived quick.', 'Starting with boats.', "I might don't be surprised by this vanist one day.", "Don't worry, everybody.", 'I had to look it up.', 'Hey, how are you?', 'We are gonna sit on this balcony and look at the Eiffel Tower', "So we already know that I want to take Haley to the equivalent of Gusto's in Ratatouille", 'Well, I see why they call this one luxury.', 'Room.', "But it doesn't look real. It's kind of furry.", 'Why is the PS4 mounted like that?', 'A beautiful vanity with lots and lots of French pastries.', 'This must be for when the kids are grounded.', 'They say things like, beautiful camp, peaceful getaway.', 'And lastly, a shower.', "And it's not every day you get to feel like that.", 'Collette kind of reminds me of Haley.', 'I mean, if you take a look at the shampoo and conditioner, they look rock solid.', 'Give it a watch.', 'That video taught me a lot of things.', 'I did feel a little uncomfortable because I was worried that people thought this was my', 'I did find the big sign that says farm.', 'Oh my gosh.', 'Because I actually just came here for a toilet here.', 'No running water at this farm.', 'The chickens would not leave.', 'I want to explore it.', "go follow Joyride's Weets on Instagram.", 'but nope. Not here.', "Let's see.", "because that's probably the most fun and romantic thing we could possibly do right now.", 'Those are pretty cool.', "This is making me feel lonely, but that's fine.", 'And I found this one. I really like this one.', "There's another living room with a PS4.", 'I need to call a guy named Captain Joseph.', "I'm clean.", "Meanwhile, I'm just watching Ratatouille every night.", 'The slide is really fun.', "but it's actually a guy named Albert.", "If there's anything that is good for the soul, it's going to Chili's by yourself,", 'I enjoyed my Doritos Locos Tacos and then decided to make a campfire.', 'I cannot express how fun this is.', 'I spent some time looking around the flower field', "Here's my list.", "It doesn't make sense.", 'But coming to this farm, this feels like...', 'Great, great.', "where he's gonna take me out into the ocean", "It was no Raditui, but if you can't tell, I'm really excited to watch Raditui.", 'And right next to it is a small little kitchen.', "We didn't even think about the fact that there's no oven in here.", 'I was not able to get connected during the duration of my stay.', 'more excited for Paris.', "I'm pretty sure it's in this one.", 'This feels restful. It feels like I won some sort of prize.', 'and get yourself a bag of Joyride.', 'I made it to the boats.', 'Okay, okay, we need a tour.', 'They named our school after it.', "They're good.", 'This is just such a good movie.', 'Camping was awesome.', 'That dinner was so good.', "Come back at 9 o'clock.", 'Again, we will cross that bridge when we get to it.', 'The property is 3.4 million.', "First of all, I'm a rat.", "There's no running water.", 'Here he is.', 'I actually wonder like what are these people do all day?', 'I fit in here fine.', 'Good morning.', "But what's it going to be like inside?", 'You guys are the best.', 'You know I went straight for that coffee maker so I could use one of these cute little', "So I don't know if it'll survive a ...
# Jaccard Similarity: 0.4067
